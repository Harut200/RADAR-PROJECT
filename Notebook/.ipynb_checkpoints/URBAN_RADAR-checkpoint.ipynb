# %%
import json
import sqlite3
import requests
import numpy as np
import pandas as pd
from pathlib import Path

DB_PATH = Path("../Data/DB/URBAN_RADAR.db")
BASE_URL = "https://api.tfl.gov.uk/StopPoint/"
STP_CNT = {"Waterloo Station": "490008660N", "Oxford Circus": "490000091W", 
           "Victoria Station": "490008660S", "King's Cross": "490000092K", "London Bridge": "490000093L"}

# %%
data_ = []

for stp in STP_CNT.values():
    resp = requests.get(f"{BASE_URL}{stp}/Arrivals").json()
    data_.append(resp)

data_
# Out:
# [[{'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-1464624316',
#    'operationType': 1,
#    'vehicleId': 'LA19KBK',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118061',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 1151,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:38:34Z',
#    'timeToLive': '2025-12-16T19:39:04Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1780642',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:58.35Z',
#     'read': '2025-12-16T19:18:56.163Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-67354531',
#    'operationType': 1,
#    'vehicleId': 'LA19KBN',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118001',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 431,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:26:34Z',
#    'timeToLive': '2025-12-16T19:27:04Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1874977',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:15.998Z',
#     'read': '2025-12-16T19:19:14.325Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '417973870',
#    'operationType': 1,
#    'vehicleId': 'LA19KBU',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118036',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 720,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:31:23Z',
#    'timeToLive': '2025-12-16T19:31:53Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1710279',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:38.312Z',
#     'read': '2025-12-16T19:18:36.131Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-2054538278',
#    'operationType': 1,
#    'vehicleId': 'LA19KBY',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118140',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 1691,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:47:34Z',
#    'timeToLive': '2025-12-16T19:48:04Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1869635',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:48.335Z',
#     'read': '2025-12-16T19:18:46.154Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1464851010',
#    'operationType': 1,
#    'vehicleId': 'LF69UZL',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '117966',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 185,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:22:28Z',
#    'timeToLive': '2025-12-16T19:22:58Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1857807',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:18.391Z',
#     'read': '2025-12-16T19:19:16.203Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1382351420',
#    'operationType': 1,
#    'vehicleId': 'YX13BKK',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '342062',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Parliament Hill Fields',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 1358,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:42:01Z',
#    'timeToLive': '2025-12-16T19:42:31Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1661179',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:18.391Z',
#     'read': '2025-12-16T19:19:16.203Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-37588630',
#    'operationType': 1,
#    'vehicleId': 'YY66OYC',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '342045',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Parliament Hill Fields',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 885,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:34:08Z',
#    'timeToLive': '2025-12-16T19:34:38Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1821841',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:18.391Z',
#     'read': '2025-12-16T19:19:16.203Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}}],
#  {'$type': 'Tfl.Api.Presentation.Entities.ApiError, Tfl.Api.Presentation.Entities',
#   'timestampUtc': '2025-12-16T19:19:24.9493167Z',
#   'exceptionType': 'EntityNotFoundException',
#   'httpStatusCode': 404,
#   'httpStatus': 'NotFound',
#   'relativeUri': '/StopPoint/490000091W/Arrivals',
#   'message': 'The following stop point is not recognised: 490000091W'},
#  [{'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '375966896',
#    'operationType': 1,
#    'vehicleId': 'LA19KBO',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '117903',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Moorgate, Finsbury Square',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 990,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:35:55Z',
#    'timeToLive': '2025-12-16T19:36:25Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1703270',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1891855263',
#    'operationType': 1,
#    'vehicleId': 'LA19KBP',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '117939',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Moorgate, Finsbury Square',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 1590,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:45:55Z',
#    'timeToLive': '2025-12-16T19:46:25Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1796454',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1600028195',
#    'operationType': 1,
#    'vehicleId': 'YX18KWW',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '342424',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Clapham Common',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 113,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:21:18Z',
#    'timeToLive': '2025-12-16T19:21:48Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1869635',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:58.35Z',
#     'read': '2025-12-16T19:18:56.163Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-285005047',
#    'operationType': 1,
#    'vehicleId': 'YX18KXE',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '342439',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Clapham Common',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 697,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:31:02Z',
#    'timeToLive': '2025-12-16T19:31:32Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1749839',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '2092424012',
#    'operationType': 1,
#    'vehicleId': 'YX18KXN',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '342022',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Clapham Common',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 1345,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:41:50Z',
#    'timeToLive': '2025-12-16T19:42:20Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1661179',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}}],
#  {'$type': 'Tfl.Api.Presentation.Entities.ApiError, Tfl.Api.Presentation.Entities',
#   'timestampUtc': '2025-12-16T19:19:26.1662713Z',
#   'exceptionType': 'EntityNotFoundException',
#   'httpStatusCode': 404,
#   'httpStatus': 'NotFound',
#   'relativeUri': '/StopPoint/490000092K/Arrivals',
#   'message': 'The following stop point is not recognised: 490000092K'},
#  {'$type': 'Tfl.Api.Presentation.Entities.ApiError, Tfl.Api.Presentation.Entities',
#   'timestampUtc': '2025-12-16T19:19:26.8620186Z',
#   'exceptionType': 'EntityNotFoundException',
#   'httpStatusCode': 404,
#   'httpStatus': 'NotFound',
#   'relativeUri': '/StopPoint/490000093L/Arrivals',
#   'message': 'The following stop point is not recognised: 490000093L'}]

# %%
data1 = [pred_list for pred_list in data_ if isinstance(pred_list, list)]
data1
# Out:
# [[{'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-1464624316',
#    'operationType': 1,
#    'vehicleId': 'LA19KBK',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118061',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 1151,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:38:34Z',
#    'timeToLive': '2025-12-16T19:39:04Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1780642',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:58.35Z',
#     'read': '2025-12-16T19:18:56.163Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-67354531',
#    'operationType': 1,
#    'vehicleId': 'LA19KBN',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118001',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 431,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:26:34Z',
#    'timeToLive': '2025-12-16T19:27:04Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1874977',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:15.998Z',
#     'read': '2025-12-16T19:19:14.325Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '417973870',
#    'operationType': 1,
#    'vehicleId': 'LA19KBU',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118036',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 720,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:31:23Z',
#    'timeToLive': '2025-12-16T19:31:53Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1710279',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:38.312Z',
#     'read': '2025-12-16T19:18:36.131Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-2054538278',
#    'operationType': 1,
#    'vehicleId': 'LA19KBY',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '118140',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 1691,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:47:34Z',
#    'timeToLive': '2025-12-16T19:48:04Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1869635',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:48.335Z',
#     'read': '2025-12-16T19:18:46.154Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1464851010',
#    'operationType': 1,
#    'vehicleId': 'LF69UZL',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '117966',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Highgate Village',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 185,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:22:28Z',
#    'timeToLive': '2025-12-16T19:22:58Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1857807',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:18.391Z',
#     'read': '2025-12-16T19:19:16.203Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1382351420',
#    'operationType': 1,
#    'vehicleId': 'YX13BKK',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '342062',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Parliament Hill Fields',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 1358,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:42:01Z',
#    'timeToLive': '2025-12-16T19:42:31Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1661179',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:18.391Z',
#     'read': '2025-12-16T19:19:16.203Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-37588630',
#    'operationType': 1,
#    'vehicleId': 'YY66OYC',
#    'naptanId': '490008660N',
#    'stationName': 'Lady Somerset Road',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'GY',
#    'direction': 'inbound',
#    'bearing': '316',
#    'tripId': '342045',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Parliament Hill Fields',
#    'timestamp': '2025-12-16T19:19:23.5231418Z',
#    'timeToStation': 885,
#    'currentLocation': '',
#    'towards': 'Highgate Village Or Parliament Hill Fields',
#    'expectedArrival': '2025-12-16T19:34:08Z',
#    'timeToLive': '2025-12-16T19:34:38Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1821841',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:18.391Z',
#     'read': '2025-12-16T19:19:16.203Z',
#     'sent': '2025-12-16T19:19:23Z',
#     'received': '0001-01-01T00:00:00Z'}}],
#  [{'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '375966896',
#    'operationType': 1,
#    'vehicleId': 'LA19KBO',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '117903',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Moorgate, Finsbury Square',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 990,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:35:55Z',
#    'timeToLive': '2025-12-16T19:36:25Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1703270',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1891855263',
#    'operationType': 1,
#    'vehicleId': 'LA19KBP',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '214',
#    'lineName': '214',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '117939',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Moorgate, Finsbury Square',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 1590,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:45:55Z',
#    'timeToLive': '2025-12-16T19:46:25Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1796454',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '1600028195',
#    'operationType': 1,
#    'vehicleId': 'YX18KWW',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '342424',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Clapham Common',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 113,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:21:18Z',
#    'timeToLive': '2025-12-16T19:21:48Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1869635',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:18:58.35Z',
#     'read': '2025-12-16T19:18:56.163Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '-285005047',
#    'operationType': 1,
#    'vehicleId': 'YX18KXE',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '342439',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Clapham Common',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 697,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:31:02Z',
#    'timeToLive': '2025-12-16T19:31:32Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1749839',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}},
#   {'$type': 'Tfl.Api.Presentation.Entities.Prediction, Tfl.Api.Presentation.Entities',
#    'id': '2092424012',
#    'operationType': 1,
#    'vehicleId': 'YX18KXN',
#    'naptanId': '490008660S',
#    'stationName': 'Greenwood Centre',
#    'lineId': '88',
#    'lineName': '88',
#    'platformName': 'null',
#    'direction': 'outbound',
#    'bearing': '130',
#    'tripId': '342022',
#    'baseVersion': '0',
#    'destinationNaptanId': '',
#    'destinationName': 'Clapham Common',
#    'timestamp': '2025-12-16T19:19:25.7400452Z',
#    'timeToStation': 1345,
#    'currentLocation': '',
#    'towards': 'Camden Town',
#    'expectedArrival': '2025-12-16T19:41:50Z',
#    'timeToLive': '2025-12-16T19:42:20Z',
#    'modeName': 'bus',
#    'timing': {'$type': 'Tfl.Api.Presentation.Entities.PredictionTiming, Tfl.Api.Presentation.Entities',
#     'countdownServerAdjustment': '-00:00:02.1661179',
#     'source': '2025-12-16T18:36:25.813Z',
#     'insert': '2025-12-16T19:19:08.361Z',
#     'read': '2025-12-16T19:19:06.173Z',
#     'sent': '2025-12-16T19:19:25Z',
#     'received': '0001-01-01T00:00:00Z'}}]]

# %%
data = []
peak_hrs = [7,8,9,10,16,17,18,19]

for pred_list in data1:
    for pred in pred_list:
        if isinstance(pred, dict):
            dic = {}
            dic["stop_name"] = pred.get("stationName", "")
            dic["stop_id"] = pred.get("naptanId", "")
            dic["line_id"] = pred.get("lineId", "")
            dic["destination"] = pred.get("destinationName", "")
            dic["expected_arrival"] = pred.get("expectedArrival", "")
            dic["time_to_station"] = pred.get("timeToStation", 0)
            h_t = int(pred.get("expectedArrival", "00:00:00").split("T")[1].split(":")[0])
            dic["is_peak"] = 1 if h_t in peak_hrs else 0
            data.append(dic)

data
# Out:
# [{'stop_name': 'Lady Somerset Road',
#   'stop_id': '490008660N',
#   'line_id': '214',
#   'destination': 'Highgate Village',
#   'expected_arrival': '2025-12-16T19:38:34Z',
#   'time_to_station': 1151,
#   'is_peak': 1},
#  {'stop_name': 'Lady Somerset Road',
#   'stop_id': '490008660N',
#   'line_id': '214',
#   'destination': 'Highgate Village',
#   'expected_arrival': '2025-12-16T19:26:34Z',
#   'time_to_station': 431,
#   'is_peak': 1},
#  {'stop_name': 'Lady Somerset Road',
#   'stop_id': '490008660N',
#   'line_id': '214',
#   'destination': 'Highgate Village',
#   'expected_arrival': '2025-12-16T19:31:23Z',
#   'time_to_station': 720,
#   'is_peak': 1},
#  {'stop_name': 'Lady Somerset Road',
#   'stop_id': '490008660N',
#   'line_id': '214',
#   'destination': 'Highgate Village',
#   'expected_arrival': '2025-12-16T19:47:34Z',
#   'time_to_station': 1691,
#   'is_peak': 1},
#  {'stop_name': 'Lady Somerset Road',
#   'stop_id': '490008660N',
#   'line_id': '214',
#   'destination': 'Highgate Village',
#   'expected_arrival': '2025-12-16T19:22:28Z',
#   'time_to_station': 185,
#   'is_peak': 1},
#  {'stop_name': 'Lady Somerset Road',
#   'stop_id': '490008660N',
#   'line_id': '88',
#   'destination': 'Parliament Hill Fields',
#   'expected_arrival': '2025-12-16T19:42:01Z',
#   'time_to_station': 1358,
#   'is_peak': 1},
#  {'stop_name': 'Lady Somerset Road',
#   'stop_id': '490008660N',
#   'line_id': '88',
#   'destination': 'Parliament Hill Fields',
#   'expected_arrival': '2025-12-16T19:34:08Z',
#   'time_to_station': 885,
#   'is_peak': 1},
#  {'stop_name': 'Greenwood Centre',
#   'stop_id': '490008660S',
#   'line_id': '214',
#   'destination': 'Moorgate, Finsbury Square',
#   'expected_arrival': '2025-12-16T19:35:55Z',
#   'time_to_station': 990,
#   'is_peak': 1},
#  {'stop_name': 'Greenwood Centre',
#   'stop_id': '490008660S',
#   'line_id': '214',
#   'destination': 'Moorgate, Finsbury Square',
#   'expected_arrival': '2025-12-16T19:45:55Z',
#   'time_to_station': 1590,
#   'is_peak': 1},
#  {'stop_name': 'Greenwood Centre',
#   'stop_id': '490008660S',
#   'line_id': '88',
#   'destination': 'Clapham Common',
#   'expected_arrival': '2025-12-16T19:21:18Z',
#   'time_to_station': 113,
#   'is_peak': 1},
#  {'stop_name': 'Greenwood Centre',
#   'stop_id': '490008660S',
#   'line_id': '88',
#   'destination': 'Clapham Common',
#   'expected_arrival': '2025-12-16T19:31:02Z',
#   'time_to_station': 697,
#   'is_peak': 1},
#  {'stop_name': 'Greenwood Centre',
#   'stop_id': '490008660S',
#   'line_id': '88',
#   'destination': 'Clapham Common',
#   'expected_arrival': '2025-12-16T19:41:50Z',
#   'time_to_station': 1345,
#   'is_peak': 1}]

# %%
conn = sqlite3.connect(DB_PATH)
cur = conn.cursor()

# cur.execute(
#     """
#     DROP TABLE IF EXISTS bus_arrivals;
#     """
# )

cur.execute(
    """
    CREATE TABLE IF NOT EXISTS bus_arrivals(
    id INTEGER PRIMARY KEY,
    stop_name TEXT,
    stop_id TEXT,
    line_id TEXT,
    destination TEXT,
    expected_arrival TEXT,
    time_to_station INTEGER,
    is_peak INTEGER
    );
    """
)

com_for_insert = """
    INSERT OR REPLACE INTO bus_arrivals(stop_name, stop_id, line_id, destination, expected_arrival, time_to_station, is_peak)
    VALUES(:stop_name, :stop_id, :line_id, :destination, :expected_arrival, :time_to_station, :is_peak)
    """

cur.executemany(com_for_insert, data)

conn.commit()
conn.close()

# %%
conn = sqlite3.connect(DB_PATH)
df = pd.read_sql("""SELECT * FROM bus_arrivals""", conn)
conn.close()

df
# Out:
#     id           stop_name     stop_id line_id                destination  \
# 0    1  Lady Somerset Road  490008660N     214           Highgate Village
# 1    2  Lady Somerset Road  490008660N     214           Highgate Village
# 2    3  Lady Somerset Road  490008660N     214           Highgate Village
# 3    4  Lady Somerset Road  490008660N     214           Highgate Village
# 4    5  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 5    6  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 6    7    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 7    8    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 8    9    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 9   10    Greenwood Centre  490008660S      88             Clapham Common
# 10  11    Greenwood Centre  490008660S      88             Clapham Common
# 11  12  Lady Somerset Road  490008660N     214           Highgate Village
# 12  13  Lady Somerset Road  490008660N     214           Highgate Village
# 13  14  Lady Somerset Road  490008660N     214           Highgate Village
# 14  15  Lady Somerset Road  490008660N     214           Highgate Village
# 15  16  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 16  17  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 17  18  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 18  19    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 19  20    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 20  21    Greenwood Centre  490008660S      88             Clapham Common
# 21  22    Greenwood Centre  490008660S      88             Clapham Common
# 22  23    Greenwood Centre  490008660S      88             Clapham Common
# 23  24  Lady Somerset Road  490008660N     214           Highgate Village
# 24  25  Lady Somerset Road  490008660N     214           Highgate Village
# 25  26  Lady Somerset Road  490008660N     214           Highgate Village
# 26  27  Lady Somerset Road  490008660N     214           Highgate Village
# 27  28  Lady Somerset Road  490008660N     214           Highgate Village
# 28  29  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 29  30  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 30  31    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 31  32    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 32  33    Greenwood Centre  490008660S      88             Clapham Common
# 33  34    Greenwood Centre  490008660S      88             Clapham Common
# 34  35    Greenwood Centre  490008660S      88             Clapham Common
#
#         expected_arrival  time_to_station  is_peak
# 0   2025-12-16T17:08:12Z             1172        1
# 1   2025-12-16T16:50:37Z              117        1
# 2   2025-12-16T16:53:28Z              288        1
# 3   2025-12-16T17:00:39Z              719        1
# 4   2025-12-16T16:57:58Z              558        1
# 5   2025-12-16T17:03:51Z              911        1
# 6   2025-12-16T17:17:06Z             1705        1
# 7   2025-12-16T17:01:54Z              793        1
# 8   2025-12-16T16:53:53Z              312        1
# 9   2025-12-16T16:57:56Z              555        1
# 10  2025-12-16T17:08:44Z             1203        1
# 11  2025-12-16T19:38:34Z             1341        1
# 12  2025-12-16T19:25:32Z              559        1
# 13  2025-12-16T19:31:23Z              910        1
# 14  2025-12-16T19:23:40Z              447        1
# 15  2025-12-16T19:42:01Z             1548        1
# 16  2025-12-16T19:19:13Z              180        1
# 17  2025-12-16T19:34:08Z             1075        1
# 18  2025-12-16T19:35:55Z             1202        1
# 19  2025-12-16T19:45:55Z             1802        1
# 20  2025-12-16T19:20:02Z              249        1
# 21  2025-12-16T19:31:02Z              909        1
# 22  2025-12-16T19:41:50Z             1557        1
# 23  2025-12-16T19:38:34Z             1151        1
# 24  2025-12-16T19:26:34Z              431        1
# 25  2025-12-16T19:31:23Z              720        1
# 26  2025-12-16T19:47:34Z             1691        1
# 27  2025-12-16T19:22:28Z              185        1
# 28  2025-12-16T19:42:01Z             1358        1
# 29  2025-12-16T19:34:08Z              885        1
# 30  2025-12-16T19:35:55Z              990        1
# 31  2025-12-16T19:45:55Z             1590        1
# 32  2025-12-16T19:21:18Z              113        1
# 33  2025-12-16T19:31:02Z              697        1
# 34  2025-12-16T19:41:50Z             1345        1

# %%
df["wait_time_min"] = df["time_to_station"] // 60

df
# Out:
#     id           stop_name     stop_id line_id                destination  \
# 0    1  Lady Somerset Road  490008660N     214           Highgate Village
# 1    2  Lady Somerset Road  490008660N     214           Highgate Village
# 2    3  Lady Somerset Road  490008660N     214           Highgate Village
# 3    4  Lady Somerset Road  490008660N     214           Highgate Village
# 4    5  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 5    6  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 6    7    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 7    8    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 8    9    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 9   10    Greenwood Centre  490008660S      88             Clapham Common
# 10  11    Greenwood Centre  490008660S      88             Clapham Common
# 11  12  Lady Somerset Road  490008660N     214           Highgate Village
# 12  13  Lady Somerset Road  490008660N     214           Highgate Village
# 13  14  Lady Somerset Road  490008660N     214           Highgate Village
# 14  15  Lady Somerset Road  490008660N     214           Highgate Village
# 15  16  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 16  17  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 17  18  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 18  19    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 19  20    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 20  21    Greenwood Centre  490008660S      88             Clapham Common
# 21  22    Greenwood Centre  490008660S      88             Clapham Common
# 22  23    Greenwood Centre  490008660S      88             Clapham Common
# 23  24  Lady Somerset Road  490008660N     214           Highgate Village
# 24  25  Lady Somerset Road  490008660N     214           Highgate Village
# 25  26  Lady Somerset Road  490008660N     214           Highgate Village
# 26  27  Lady Somerset Road  490008660N     214           Highgate Village
# 27  28  Lady Somerset Road  490008660N     214           Highgate Village
# 28  29  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 29  30  Lady Somerset Road  490008660N      88     Parliament Hill Fields
# 30  31    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 31  32    Greenwood Centre  490008660S     214  Moorgate, Finsbury Square
# 32  33    Greenwood Centre  490008660S      88             Clapham Common
# 33  34    Greenwood Centre  490008660S      88             Clapham Common
# 34  35    Greenwood Centre  490008660S      88             Clapham Common
#
#         expected_arrival  time_to_station  is_peak  wait_time_min
# 0   2025-12-16T17:08:12Z             1172        1             19
# 1   2025-12-16T16:50:37Z              117        1              1
# 2   2025-12-16T16:53:28Z              288        1              4
# 3   2025-12-16T17:00:39Z              719        1             11
# 4   2025-12-16T16:57:58Z              558        1              9
# 5   2025-12-16T17:03:51Z              911        1             15
# 6   2025-12-16T17:17:06Z             1705        1             28
# 7   2025-12-16T17:01:54Z              793        1             13
# 8   2025-12-16T16:53:53Z              312        1              5
# 9   2025-12-16T16:57:56Z              555        1              9
# 10  2025-12-16T17:08:44Z             1203        1             20
# 11  2025-12-16T19:38:34Z             1341        1             22
# 12  2025-12-16T19:25:32Z              559        1              9
# 13  2025-12-16T19:31:23Z              910        1             15
# 14  2025-12-16T19:23:40Z              447        1              7
# 15  2025-12-16T19:42:01Z             1548        1             25
# 16  2025-12-16T19:19:13Z              180        1              3
# 17  2025-12-16T19:34:08Z             1075        1             17
# 18  2025-12-16T19:35:55Z             1202        1             20
# 19  2025-12-16T19:45:55Z             1802        1             30
# 20  2025-12-16T19:20:02Z              249        1              4
# 21  2025-12-16T19:31:02Z              909        1             15
# 22  2025-12-16T19:41:50Z             1557        1             25
# 23  2025-12-16T19:38:34Z             1151        1             19
# 24  2025-12-16T19:26:34Z              431        1              7
# 25  2025-12-16T19:31:23Z              720        1             12
# 26  2025-12-16T19:47:34Z             1691        1             28
# 27  2025-12-16T19:22:28Z              185        1              3
# 28  2025-12-16T19:42:01Z             1358        1             22
# 29  2025-12-16T19:34:08Z              885        1             14
# 30  2025-12-16T19:35:55Z              990        1             16
# 31  2025-12-16T19:45:55Z             1590        1             26
# 32  2025-12-16T19:21:18Z              113        1              1
# 33  2025-12-16T19:31:02Z              697        1             11
# 34  2025-12-16T19:41:50Z             1345        1             22

# %%
df["stop_name"].value_counts().idxmax()
# Out:
# 'Lady Somerset Road'

# %%
df.groupby("stop_name")["is_peak"].sum().idxmax()
# Out:
# 'Lady Somerset Road'

# %%
df.groupby("stop_name")["time_to_station"].mean().idxmax()
# Out:
# 'Greenwood Centre'

# %%
df["wait_time_min"].mean()
# Out:
# np.float64(14.485714285714286)
